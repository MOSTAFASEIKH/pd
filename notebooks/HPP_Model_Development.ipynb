# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("AI/ML Notebook Ready")
# Out:
# AI/ML Notebook Ready

# %%
import sys

print(sys.executable)
# Out:
# C:\Users\INDIA\Desktop\AI-ML-project\HPP\venv\Scripts\python.exe
